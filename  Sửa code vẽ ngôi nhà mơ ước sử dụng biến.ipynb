# %%
import turtle
v = turtle.Turtle()
turtle.bgcolor('sky blue')
v.pensize(2)
v.fillcolor('yellow')
v.speed(10)
phai1 = 60
phai2 = 45
phai3 = 90
phai4 = 135
trai1 = 60
trai2 = 80
trai3 = 90
trai4 = 120
dai   = 115
dai1  = 80
dai2  = 120
dai3  = 150
dai4  = 240
dai5  = 360
#vẽ tường bên phải
v.begin_fill()  
v.right(phai3)
v.forward(360)
v.right(phai1)
v.forward(240)
v.right(120)
v.forward(360)
v.right(phai1)
v.forward(240)
v.end_fill()
#vẽ cửa sổ
v.fillcolor('maroon')
v.begin_fill() 
v.penup()
v.rt(140)
v.fd(170)
v.pendown()
v.rt(40)
v.fd(dai1)
v.lt(trai1)
v.fd(dai1)
v.lt(trai4)
v.fd(dai1)
v.lt(trai1)
v.fd(dai1)
v.end_fill()
v.penup()
v.lt(-20)
v.fd(170)
v.pendown()
v.lt(70)
#vẽ mãi phải
v.fillcolor('orange')
v.begin_fill() 
v.forward(dai4)
v.left(70)
v.forward(dai4)
v.left(110)
v.forward(dai4)
v.end_fill()
#vẽ mái giữa
v.fillcolor('magenta')
v.begin_fill()
v.right(140)
v.forward(dai5)
v.right(139)
v.forward(dai4)
v.end_fill()
#
v.penup()
v.back(240)
v.pendown()
#vẽ tường trước cửa
v.fillcolor('blue')
v.begin_fill() 
v.right(131)
v.fd(dai5)
v.lt(trai3)
v.fd(dai5)
v.lt(trai3)
v.fd(dai5)
v.lt(trai3)
v.fd(dai5)
v.end_fill()
#
v.penup()
v.lt(trai3)
v.fd(dai5)
v.pendown()
#vẽ cửa
v.fillcolor('lime')
v.begin_fill() 
v.lt(trai3)
v.fd(dai2)
v.lt(trai3)
v.fd(dai3)
v.rt(phai3)
v.fd(dai2)
v.rt(phai3)
v.fd(dai3)
v.rt(phai3)
v.fd(dai2)
v.end_fill()
#vẽ thân cây
v.penup()
v.lt(180)
v.fd(700)
v.pendown()
v.fillcolor('brown')
v.begin_fill() 
v.fd(50)
v.lt(trai3)
v.fd(dai3)
v.lt(trai3)
v.fd(50)
v.lt(trai3)
v.fd(dai3)
v.end_fill()
v.penup()
v.lt(180)
v.fd(255)
v.rt(phai3)
v.fd(25)
v.pendown()
#vẽ lá
v.fillcolor('mediumseagreen')
v.begin_fill() 
v.rt(phai2)
v.fd(dai3)
v.rt(phai4)
v.fd(210)
v.rt(phai4)
v.fd(dai3)
v.end_fill()
#
v.fillcolor('mediumseagreen')
v.begin_fill() 
v.lt(135)
v.fd(105)
v.rt(phai4)
v.fd(dai3)
v.rt(phai3)
v.fd(dai3)
v.rt(phai4)
v.fd(106)
v.end_fill()
#
v.fillcolor('mediumseagreen')
v.begin_fill() 
v.penup()
v.rt(phai3)
v.fd(106)
v.pendown()
v.lt(trai3)
v.fd(105)
v.rt(phai4)
v.fd(dai3)
v.rt(phai3)
v.fd(dai3)
v.rt(phai4)
v.fd(107)
v.end_fill()
v.penup()
v.fd(dai3)
v.rt(phai3)
v.fd(400)
v.pendown()
v.lt(trai3)
v.fd(dai3)
v.back(dai3)
#
v.rt(phai2)
v.fd(dai)
v.back(dai)
#
v.rt(phai2)
v.fd(dai3)
v.back(dai3)
#
v.rt(phai2)
v.fd(dai)
v.back(dai)
#
#
v.rt(phai2)
v.fd(dai3)
v.back(dai3)
#
v.rt(phai2)
v.fd(dai)
v.back(dai)
#
#
v.rt(phai2)
v.fd(dai3)
v.back(dai3)
#
v.rt(phai2)
v.fd(dai)
v.back(dai)
v.rt(135)
v.back(70)
v.fillcolor('yellow')
v.begin_fill()  
v.rt(phai3)
v.circle(70)
v.end_fill()


turtle.done()
