# %%
import turtle
v = turtle.Turtle()
v.pensize(2)
v.speed(10)
#
v.fillcolor('red')
v.begin_fill()
v.fd(500)
v.lt(90)
v.fd(250)
v.lt(90)
v.fd(500)
v.lt(90)
v.fd(250)
v.rt(180)
v.end_fill()
#
v.penup()
v.goto(200,0)
v.pendown()
v.fillcolor('blue')
v.begin_fill()
v.fd(150)
v.rt(90)
v.fd(100)
v.rt(90)
v.fd(150)
v.end_fill()
#
v.penup()
v.goto(0,250)
v.pendown()
v.fillcolor('yellow')
v.begin_fill()
v.lt(135)
v.fd(250)
v.rt(90)
v.fd(250)
v.end_fill()
#
v.fillcolor('black')
v.begin_fill()
v.back(140)
v.lt(135)
v.fd(50)
v.rt(90)
v.fd(30)
v.rt(90)
v.fd(80)
v.end_fill()
#
v.penup()
v.back(100)
v.pendown()
v.rt(180)
v.fd(70)
v.lt(90)
v.penup()
v.fd(30)
v.lt(90)
v.fd(10)
v.pendown()
v.fd(40)
#Vẽ Cây
v.penup()
v.goto(-120,-100)
v.pendown()
v.fillcolor('antiquewhite')
v.begin_fill()
v.lt(90)
v.fd(50)
v.lt(95)
v.fd(100)
v.lt(85)
v.fd(25)
v.lt(80)
v.fd(100)
v.end_fill()
#
v.penup()
v.home()
v.goto(-150,0)
v.pendown()
v.fillcolor('green')
v.begin_fill()
v.fd(120)
v.lt(135)
v.fd(80)
v.lt(87)
v.fd(85)
v.end_fill()
#
v.penup()
v.home()
v.goto(-135,55)
v.pendown()
v.fillcolor('green')
v.begin_fill()
v.fd(100)
v.lt(135)
v.fd(70)
v.lt(89)
v.fd(70)
v.end_fill()
#
v.penup()
v.home()
v.goto(-115,105)
v.pendown()
v.fillcolor('green')
v.begin_fill()
v.fd(65)
v.lt(135)
v.fd(50)
v.lt(93)
v.fd(45)
v.end_fill()
#vẽ cây 2
v.penup()
v.home()
v.goto(700,-60)
v.pendown()
v.fillcolor('cornsilk')
v.begin_fill()
v.fd(70)
v.lt(100)
v.fd(100)
v.lt(80)
v.fd(35)
v.lt(80)
v.fd(100)
v.lt(100)
v.end_fill()
#
v.penup()
v.goto(645,38)
v.pendown()
v.fillcolor('green')
v.begin_fill()
v.fd(190)
v.lt(130)
v.fd(150)
v.lt(100)
v.fd(150)
v.end_fill()
#
v.penup()
v.goto(680,154)
v.pendown()
v.fillcolor('green')
v.begin_fill()
v.lt(130)
v.fd(135)
v.lt(135)
v.fd(100)
v.lt(92)
v.fd(95)
v.end_fill()
#
v.penup()
v.home()
v.goto(705,225)
v.pendown()
v.fillcolor('green')
v.begin_fill()
v.fd(90)
v.lt(135)
v.fd(70)
v.lt(92)
v.fd(70)
v.end_fill()





turtle.done()
