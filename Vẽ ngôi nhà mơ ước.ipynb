# %%
import turtle
v = turtle.Turtle()
turtle.bgcolor('sky blue')
v.pensize(2)
v.fillcolor('yellow')
v.speed(10)
v.begin_fill()  
v.right(90)
v.forward(350)
v.right(60)
v.forward(240)
v.right(120)
v.forward(350)
v.right(60)
v.forward(240)
v.end_fill()
#
v.fillcolor('maroon')
v.begin_fill() 
v.penup()
v.rt(140)
v.fd(170)
v.pendown()
v.rt(40)
v.fd(80)
v.lt(60)
v.fd(80)
v.lt(120)
v.fd(80)
v.lt(60)
v.fd(80)
v.end_fill()
v.penup()
v.lt(-20)
v.fd(170)
v.pendown()
v.lt(70)

#
v.fillcolor('orange')
v.begin_fill() 
v.forward(240)
v.left(70)
v.forward(240)
v.left(110)
v.forward(240)
v.end_fill()
#
v.fillcolor('magenta')
v.begin_fill()
v.right(140)
v.forward(360)
v.right(139)
v.forward(245)
v.end_fill()
#
v.penup()
v.back(245)
v.pendown()
#
v.fillcolor('blue')
v.begin_fill() 
v.right(131)
v.fd(350)
v.lt(90)
v.fd(360)
v.lt(90)
v.fd(350)
v.lt(90)
v.fd(360)
v.end_fill()
#
v.penup()
v.lt(90)
v.fd(350)
v.pendown()
#
v.fillcolor('lime')
v.begin_fill() 
v.lt(90)
v.fd(120)
v.lt(90)
v.fd(150)
v.rt(90)
v.fd(120)
v.rt(90)
v.fd(150)
v.rt(90)
v.fd(120)
v.end_fill()
#
v.penup()
v.lt(180)
v.fd(700)
v.pendown()
v.fillcolor('brown')
v.begin_fill() 
v.fd(50)
v.lt(90)
v.fd(150)
v.lt(90)
v.fd(50)
v.lt(90)
v.fd(150)
v.end_fill()
v.penup()
v.lt(180)
v.fd(255)
v.rt(90)
v.fd(25)
v.pendown()
#
v.fillcolor('mediumseagreen')
v.begin_fill() 
v.rt(45)
v.fd(150)
v.rt(135)
v.fd(210)
v.rt(135)
v.fd(150)
v.end_fill()
#
v.fillcolor('mediumseagreen')
v.begin_fill() 
v.lt(135)
v.fd(105)
v.rt(135)
v.fd(150)
v.rt(90)
v.fd(150)
v.rt(135)
v.fd(106)
v.end_fill()
#
v.fillcolor('mediumseagreen')
v.begin_fill() 
v.penup()
v.rt(90)
v.fd(106)
v.pendown()
v.lt(90)
v.fd(105)
v.rt(135)
v.fd(150)
v.rt(90)
v.fd(150)
v.rt(135)
v.fd(107)
v.end_fill()
v.penup()
v.fd(150)
v.rt(90)
v.fd(400)
v.pendown()
v.lt(90)
v.fd(150)
v.back(150)
#
v.rt(45)
v.fd(115)
v.back(115)
#
v.rt(45)
v.fd(150)
v.back(150)
#
v.rt(45)
v.fd(115)
v.back(115)
#
#
v.rt(45)
v.fd(150)
v.back(150)
#
v.rt(45)
v.fd(115)
v.back(115)
#
#
v.rt(45)
v.fd(150)
v.back(150)
#
v.rt(45)
v.fd(115)
v.back(115)
v.rt(135)
v.back(70)
v.fillcolor('yellow')
v.begin_fill()  
v.rt(90)
v.circle(70)
v.end_fill()


turtle.done()
